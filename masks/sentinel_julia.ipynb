# %%
using GeoArrays
using ImageShow
using ArchGDAL; const AG = ArchGDAL
using Plots

# %%
TCI_path = "S2A_MSIL1C_20221101T151711_N0400_R125_T18NYN_20221101T183841.SAFE/GRANULE/L1C_T18NYN_A038446_20221101T151708/IMG_DATA/T18NYN_20221101T151711_TCI.jp2"
TCI = AG.read(TCI_path)
cloud_path = "cloud_20221101T183841.img"
img_cloud = AG.read(cloud_path)
img_cloud
# Out:
# GDAL Dataset (Driver: HFA/Erdas Imagine Images (.img))
# File(s):
#   cloud_20221101T183841.img
#   cloud_20221101T183841.img.aux.xml
#
# Dataset (width x height): 5490 x 5490 (pixels)
# Number of raster bands: 1
#   [GA_ReadOnly] Band 1 (Palette): 5490 x 5490 (UInt8)

# %%
AG.imread(img_cloud)
# Out:
# 5490×5490 PermutedDimsArray(mappedarray(RGBA{FixedPointNumbers.N0f8}, ImageCore.extractchannels, reinterpret(FixedPointNumbers.N0f8, ::Matrix{UInt8}), reinterpret(FixedPointNumbers.N0f8, ::Matrix{UInt8}), reinterpret(FixedPointNumbers.N0f8, ::Matrix{UInt8}), reinterpret(FixedPointNumbers.N0f8, ::Matrix{UInt8})), (2, 1)) with eltype RGBA{FixedPointNumbers.N0f8}:
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)  …  RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)  …  RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(1.0,0.0,1.0,1.0)
# ...

# %%
AG.imread(TCI)
# Out:
# 10980×10980 PermutedDimsArray(mappedarray(RGB{FixedPointNumbers.N0f8}, ImageCore.extractchannels, reinterpret(FixedPointNumbers.N0f8, ::Matrix{UInt8}), reinterpret(FixedPointNumbers.N0f8, ::Matrix{UInt8}), reinterpret(FixedPointNumbers.N0f8, ::Matrix{UInt8})), (2, 1)) with eltype RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(1.0,1.0,1.0)
# ...
